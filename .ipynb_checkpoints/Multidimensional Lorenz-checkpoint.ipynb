# %% [markdown]
# # Multidimensional differential equations
#
# - Börge Göbel

# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy import integrate

# %% [markdown]
# ## Lorenz system

# %% [markdown]
# We solve the three coupled differential equations
#
# $$\dot{x} = a(y-x)$$
# $$\dot{y} = x(b-z)-y$$
# $$\dot{z} = xy-cz$$
#
# Here \\( x,y,z \\) are the coordinates and \\( a,b,c \\) are coefficients

# %%
def f_ODE(t, r, a, b, c):
    x, y, z = r
    x1 = a*(y-x)
    y1 = x*(b-z) - y
    z1 = x*y - c*z
    return ([x1, y1, z1])

# %% [markdown]
# ### Chaotic solution: For b > 24.74, two repulsive points exist

# %%
a = 10.0
b = 50.0
c = 8.0/3

tStart = 0
tEnd = 50

x0 = 1.0
y0 = 0.0
z0 = 0.0

solution = integrate.solve_ivp(f_ODE, [tStart, tEnd], [x0, y0, z0], method = "RK45", t_eval=np.linspace(tStart, tEnd, 5001), args=(a, b, c))

# %%
plot_traj = plt.axes(projection="3d")
plot_traj.plot3D(solution.y[0], solution.y[1], solution.y[2], linewidth=0.5)

# %%
solution2 = integrate.solve_ivp(f_ODE, [tStart, tEnd], [1.1*x0, y0, z0], method = "RK45", t_eval=np.linspace(tStart, tEnd, 5001), args=(a, b, c))

# %%
plot_traj = plt.axes(projection="3d")
plot_traj.plot3D(solution.y[0], solution.y[1], solution.y[2], linewidth=0.5)
plot_traj.plot3D(solution2.y[0], solution2.y[1], solution2.y[2], linewidth=0.5)

# %% [markdown]
# Below and above we see that on changing the initial conditions, the trajectory changes and this is what we mean by chaos!

# %%
solution.y[:, -1]
# Out:
# array([10.74272658, 21.0668307 , 31.29407404])

# %%
solution2.y[:, -1]
# Out:
# array([-11.78604861, -17.41325428,  44.25937873])

# %%
plt.plot(solution.t, solution.y[0])

# %% [markdown]
# ### Non-chaotic solution: For b < 24.74, the two points become attractive

# %%
a = 10.0
b = 20.0
c = 8.0/3

tStart = 0
tEnd = 50

x0 = 1.0
y0 = 0.0
z0 = 0.0

solution = integrate.solve_ivp(f_ODE, [tStart, tEnd], [x0, y0, z0], method = "RK45", t_eval=np.linspace(tStart, tEnd, 5001), args=(a, b, c))
solution2 = integrate.solve_ivp(f_ODE, [tStart, tEnd], [1.1*x0, 0.5+y0, 3.5+z0], method = "RK45", t_eval=np.linspace(tStart, tEnd, 5001), args=(a, b, c))

# %%
plot_traj = plt.axes(projection="3d")
plot_traj.plot3D(solution.y[0], solution.y[1], solution.y[2], linewidth=0.5, label="1, 0, 0")
plot_traj.plot3D(solution2.y[0], solution2.y[1], solution2.y[2], linewidth=0.5, label="1.1, 0.5, 3.5")
plt.legend()

# %% [markdown]
# The above case is called a Lorenz attractor. In this case, even if we perturb the initial conditions `slightly`, the function always converges to the same point, hence the name, attractor!
